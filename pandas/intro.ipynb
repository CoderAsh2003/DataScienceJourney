# %%
import pandas as pd

df = pd.read_csv('movies.csv') #df or data frame is a main object in py library which has tabular data

#df.head(num_rows) - Prints only that many records of that dataset (from top)

#df.tail(num_records) - Prints records of dataset (from bottom)

df.head(2)


#df.sample(num_records) - Randomly print records from the dataset



#Slicing is also possible like df[2:6]

df.shape #Dimension of the dataset

#You can print a specific attribute by two methods

#Method -1
#df['attribute_name']

#Method-2
#df.attriute_name

df.Genre

#type(df.attribute_name) -Prints the data type of the attribute

type(df.Genre)
# Out:
# pandas.core.series.Series

# %%
#Pandas has readymade functions for min,max,std_deviation etc whihc makes it easier to handle data and derive a specific result from it

#Lets use rotten_tomatoes as reference here

print(f"Minimum rotten tomatoes rating is: {df['Rotten Tomatoes %'].min()} ")
# Out:
# Minimum rotten tomatoes rating is: 3

# %%
df.head(2)
# Out:
#                          Film    Genre            Lead Studio  \
# 0  Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1             Youth in Revolt   Comedy  The Weinstein Company
#
#    Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 0                70       1.747542                 64         $41.94   2008
# 1                52       1.090000                 68         $19.62   2010

# %%
df.tail(3)
# Out:
#                     Film   Genre  Lead Studio  Audience score %  \
# 74    A Dangerous Method   Drama  Independent                89
# 75            27 Dresses  Comedy          Fox                71
# 76  (500) Days of Summer  comedy          Fox                81
#
#     Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 74       0.448645                 79          $8.97   2011
# 75       5.343622                 40        $160.31   2008
# 76       8.096000                 87         $60.72   2009

# %%
df.sample(6)
# Out:
#                          Film   Genre            Lead Studio  \
# 21           The Back-up Plan  Comedy                    CBS
# 63         Going the Distance  Comedy           Warner Bros.
# 59  I Love You Phillip Morris  Comedy            Independent
# 1             Youth in Revolt  Comedy  The Weinstein Company
# 56                Just Wright  Comedy                    Fox
# 48               Love Happens   Drama              Universal
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# 21                47       2.202571                 20         $77.09   2010
# 63                56       1.314062                 53         $42.05   2010
# 59                57       1.340000                 71         $20.10   2010
# 1                 52       1.090000                 68         $19.62   2010
# 56                58       1.797417                 45         $21.57   2010
# 48                40       2.004444                 18         $36.08   2009

# %%
#Lets say i want a seperate df for genre wise

dfr = df[df.Genre == 'Romance']
dfr

dfc = df[df.Genre == 'Comedy']
dfc
# Out:
#                                   Film   Genre            Lead Studio  \
# 1                      Youth in Revolt  Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger  Comedy            Independent
# 3                         When in Rome  Comedy                 Disney
# 4                What Happens in Vegas  Comedy                    Fox
# 9                      Valentine's Day  Comedy           Warner Bros.
# 13                      The Ugly Truth  Comedy            Independent
# 16                        The Proposal  Comedy                 Disney
# 17              The Invention of Lying  Comedy           Warner Bros.
# 18                  The Heartbreak Kid  Comedy              Paramount
# 21                    The Back-up Plan  Comedy                    CBS
# 24              She's Out of My League  Comedy              Paramount
# 25                Sex and the City Two  Comedy           Warner Bros.
# ...
